# %%
#SET HOME DIRECTORY
import os
HOME = os.getcwd()
print(HOME)

# %%
from IPython.display import display, Image
import glob

# %%
#FILES OBTAINED AFTER TRAINING
# !ls latest_runs/results
# Out:
# args.yaml					    train_batch1.jpg
# confusion_matrix.png				    train_batch2.jpg
# events.out.tfevents.1712403142.e037c3690745.3053.0  train_batch435.jpg
# F1_curve.png					    train_batch436.jpg
# P_curve.png					    val_batch0_labels.jpg
# PR_curve.png					    val_batch0_pred.jpg
# R_curve.png					    val_batch1_labels.jpg
# results.csv					    val_batch1_pred.jpg
# results.png					    val_batch2_labels.jpg
# train_batch0.jpg				    val_batch2_pred.jpg

# %%
#CONFUSION MATRIX
Image(filename=f'/home/hemanth/ADAS-Blind-Spot-Detection/latest_runs/results/confusion_matrix.png', width=600)

# %%
#F1-CURVE
Image(filename=f'/home/hemanth/ADAS-Blind-Spot-Detection/latest_runs/results/F1_curve.png', width=600)

# %%
#P-CURVE
Image(filename=f'/home/hemanth/ADAS-Blind-Spot-Detection/latest_runs/results/P_curve.png', width=600)

# %%
#PR-CURVE
Image(filename=f'/home/hemanth/ADAS-Blind-Spot-Detection/latest_runs/results/PR_curve.png', width=600)

# %%
#R-CURVE
Image(filename=f'/home/hemanth/ADAS-Blind-Spot-Detection/latest_runs/results/R_curve.png', width=600)

# %%
#RESULTS
Image(filename=f'/home/hemanth/ADAS-Blind-Spot-Detection/latest_runs/results/results.png', width=600)

# %%
#SAMPLE-IMAGES
Image(filename=f'/home/hemanth/ADAS-Blind-Spot-Detection/latest_runs/results/train_batch0.jpg', width=600)

# %%
#SAMPLE-PREDICTIONS
for image_path in glob.glob(f'{HOME}/runs/detect/predict/*.jpg')[:5]:
      display(Image(filename=image_path))
      print("\n")
